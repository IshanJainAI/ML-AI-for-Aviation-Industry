# %% [markdown]
# ## Objective: to identify which customer will buy Insurance.

# %% [markdown]
# ### Binaray Classification with LightGBM, Random Forest, Logistic Regression

# %% [markdown]
# In this Notebook, 'ROUTE' are considered - Top routes.
#
#
# ['ICNPEN','KTMPEN','CGKHND','JHBKTM','MELPEN','DMKKIX','PENTPE','AKLKUL']

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
cd ../gdrive/My Drive/Colab Notebooks/_Location Intelligence

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
import xgboost as xgb
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, RandomForestRegressor, RandomForestClassifier
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV 
from sklearn.metrics import mean_absolute_error, accuracy_score, confusion_matrix, classification_report, roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.metrics import roc_curve
from sklearn.metrics import f1_score
from sklearn import preprocessing
from sklearn.metrics import precision_recall_curve

# %%
# Function to generate Confusion matrix
def confusion_matrix_custom(act, predict):
  # Compute Confusion matrix
  print("Actual, Predicted Observations:  ",len(act), len(predict))
  anpn = 0
  anpy = 0
  aypn = 0
  aypy = 0
  
  for i in range(len(act)):
      if (act[i]==0 and predict[i]==0):
          anpn = anpn + 1
      elif (act[i]==0 and predict[i]==1):
          anpy = anpy + 1
      elif (act[i]==1 and predict[i]==0):
          aypn = aypn + 1
      else:
          aypy = aypy + 1
  # Confusoin matrix
  print ("--------------------------------------------")
  print ("Confusion Matrix")
  print ("--------------------------------------------")
  print ("              ", "Predicted N", "Predicted Y")
  print ("Actual N      ", anpn,"          ", anpy) 
  print ("Actual Y      ", aypn,"          ", aypy)
  print ("--------------------------------------------")
  print ("Total observations  :  ", anpn+anpy+aypn+aypy)
  print ("False Positives     :  ", anpy)
  print ("False Negatives     :  ", aypn)
  print ("Overall Accuracy    :  ", round((float(anpn+aypy)/float(anpn+anpy+aypn+aypy))*100, 2), "%")
  print ("Sensitivity/Recall  :  ", round((float(aypy)/float(aypn+aypy))*100, 2), "%")
  print ("Specificity         :  ", round((float(anpn)/float(anpn+anpy))*100, 2), "%")
  print ("Precision           :  ", round((float(aypy)/float(anpy+aypy))*100, 2), "%")
  print ("--------------------------------------------")

# %%
data = pd.read_csv("Classification with FlightRoute of SpiceJet/AncillaryScoring_insurance.csv",encoding='latin-1')

# %%
data = data[data['ROUTE'].isin(['ICNPEN','KTMPEN','CGKHND','JHBKTM','MELPEN','DMKKIX','PENTPE','AKLKUL'])]
## These are 7 routes with above 100 INS_FLAG

# %% [markdown]
# ### EDA & Preprocessing (Routes)

# %%
data_classA = data[data['INS_FLAG'] == 0]
data_classB = data[data['INS_FLAG'] == 1]

# Visualizing the relation between numerical variables and target variable
cols = data.columns
for i in cols:
    plt.hist(data_classA[i],color='blue')
    plt.hist(data_classB[i], color='red')
    plt.xlabel(i)
    plt.show()

# %%
# Removing ID column 
len(data['Id'].unique()) # 50000 , which is equal to the number of rows, this may be dropped

data.drop(['Id'], axis=1,inplace=True)
data.shape
# Out:
# (6408, 14)

# %%
# Histograms
for i in data.columns:
    plt.hist(data[i])
    plt.xlabel(i)
    plt.show()

# %%
# Correlation Matrix
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

string_cols = ['SALESCHANNEL','TRIPTYPEDESC','flight_day','ROUTE','geoNetwork_country']

for i in string_cols:
    le.fit(data[i])
    data[i] = le.transform(data[i])
    
data.head(3)
# Out:
#     PAXCOUNT  SALESCHANNEL  TRIPTYPEDESC  PURCHASELEAD  LENGTHOFSTAY  \
# 82         1             0             2            15            31
# 83         1             0             2            31           274
# 84         1             0             2           316            35
#
#     flight_hour  flight_day  ROUTE  geoNetwork_country  BAGGAGE_CATEGORY  \
# 82           17           1      0                  35                 0
# 83           10           5      0                  35                 1
# 84           16           5      0                  35                 1
#
#     SEAT_CATEGORY  FNB_CATEGORY  INS_FLAG  flightDuration_hour
# 82              0             0         1                 8.83
# 83              0             0         0                 8.83
# 84              0             0         0                 8.83

# %%
# Checking the No. of Unique Values.
for i in data.columns:
    print("{}:{}".format(i,len(data[i].unique())))
# Out:
# PAXCOUNT:9
# SALESCHANNEL:2
# TRIPTYPEDESC:3
# PURCHASELEAD:430
# LENGTHOFSTAY:196
# flight_hour:24
# flight_day:7
# ROUTE:8
# geoNetwork_country:71
# BAGGAGE_CATEGORY:2
# SEAT_CATEGORY:2
# FNB_CATEGORY:2
# INS_FLAG:2
# flightDuration_hour:6

# %%
num_cols = list(data.columns)

for i in string_cols:
    num_cols.remove(i)
    
num_cols.remove('INS_FLAG')

# %% [markdown]
# ### Train & Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop(['INS_FLAG'], axis=1)
y = data['INS_FLAG']

# %%
X.columns
# Out:
# Index(['PAXCOUNT', 'SALESCHANNEL', 'TRIPTYPEDESC', 'PURCHASELEAD',
#        'LENGTHOFSTAY', 'flight_hour', 'flight_day', 'ROUTE',
#        'geoNetwork_country', 'BAGGAGE_CATEGORY', 'SEAT_CATEGORY',
#        'FNB_CATEGORY', 'flightDuration_hour'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# ## LightGBM

# %%
from lightgbm import LGBMClassifier

# %% [markdown]
# #### Prediction

# %%
clf = LGBMClassifier(is_unbalance = True).fit(X_train.values,y_train)
predictions = clf.predict(X_test)

# %% [markdown]
# #### Confusion Matrix

# %%
print(confusion_matrix(y_test, predictions))
print("="*60)
print(classification_report(y_test, predictions))
print("F1 Score : {}".format(f1_score(y_test,predictions)))
# Out:
# [[313 161]
#  [ 64 103]]
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.83      0.66      0.74       474
#            1       0.39      0.62      0.48       167
#
#     accuracy                           0.65       641
#    macro avg       0.61      0.64      0.61       641
# weighted avg       0.72      0.65      0.67       641
#
# F1 Score : 0.4779582366589326

# %%
act = y_test.values
predict = predictions
confusion_matrix_custom(act, predict)
# Out:
# Actual, Predicted Observations:   641 641
# --------------------------------------------
# Confusion Matrix
# --------------------------------------------
#                Predicted N Predicted Y
# Actual N       313            161
# Actual Y       64            103
# --------------------------------------------
# Total observations  :   641
# False Positives     :   161
# False Negatives     :   64
# Overall Accuracy    :   64.9 %
# Sensitivity/Recall  :   61.68 %
# Specificity         :   66.03 %
# Precision           :   39.02 %
# --------------------------------------------

# %% [markdown]
# #### RoC and AUC

# %%
probs = clf.predict_proba(X_test)  
probs = probs[:, 1] 
fper, tper, thresholds = roc_curve(y_test, probs) 
plt.plot(fper, tper)
plt.plot([0,1], [0,1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('LGBM ROC curve')
# show the plot
plt.show()

print("The AUC ROC Score is {}".format(roc_auc_score(y_test, predictions)))
# Out:
# The AUC ROC Score is 0.6385520099042421

# %% [markdown]
# #### Feature importance

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

importance = clf.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
figure(figsize=(20, 20))
plt.bar([x for x in range(len(importance))], importance)
plt.xticks(list(range(0,13)))
plt.show()
# # 3,4,5,7,8,12
# Out:
# Feature: 0, Score: 130.00000
# Feature: 1, Score: 40.00000
# Feature: 2, Score: 0.00000
# Feature: 3, Score: 886.00000
# Feature: 4, Score: 571.00000
# Feature: 5, Score: 461.00000
# Feature: 6, Score: 294.00000
# Feature: 7, Score: 104.00000
# Feature: 8, Score: 205.00000
# Feature: 9, Score: 73.00000
# Feature: 10, Score: 58.00000
# Feature: 11, Score: 88.00000
# Feature: 12, Score: 90.00000

# %%
X.columns
# Out:
# Index(['PAXCOUNT', 'SALESCHANNEL', 'TRIPTYPEDESC', 'PURCHASELEAD',
#        'LENGTHOFSTAY', 'flight_hour', 'flight_day', 'ROUTE',
#        'geoNetwork_country', 'BAGGAGE_CATEGORY', 'SEAT_CATEGORY',
#        'FNB_CATEGORY', 'flightDuration_hour'],
#       dtype='object')

# %% [markdown]
# ## Random Forest Classifier

# %% [markdown]
# #### Oversampling with SMOTE

# %%
# import the SMOTETomek
from imblearn.over_sampling import SMOTE

# create the  object with the desired sampling strategy.
smote = SMOTE(sampling_strategy='minority')

# fit the object to our training data
X_train_smote, Y_train_smote = smote.fit_sample(X_train, y_train)

# %%
from collections import Counter
counter = Counter(Y_train_smote)
print(counter)
# Out:
# Counter({0: 4120, 1: 4120})

# %%
clf_rfc = RandomForestClassifier().fit(X_train_smote,Y_train_smote)
predictions_rfc = clf_rfc.predict(X_test.values)

# %%
print(confusion_matrix(y_test, predictions_rfc))
print("="*60)
print(classification_report(y_test, predictions_rfc))

print("F1 Score : {}".format(f1_score(y_test,predictions_rfc)))
# plot roc auc
# Out:
# [[380  94]
#  [105  62]]
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.78      0.80      0.79       474
#            1       0.40      0.37      0.38       167
#
#     accuracy                           0.69       641
#    macro avg       0.59      0.59      0.59       641
# weighted avg       0.68      0.69      0.69       641
#
# F1 Score : 0.38390092879256965

# %%
act = y_test.values
predict = predictions_rfc
confusion_matrix_custom(act, predict)
# Out:
# Actual, Predicted Observations:   641 641
# --------------------------------------------
# Confusion Matrix
# --------------------------------------------
#                Predicted N Predicted Y
# Actual N       380            94
# Actual Y       105            62
# --------------------------------------------
# Total observations  :   641
# False Positives     :   94
# False Negatives     :   105
# Overall Accuracy    :   68.95 %
# Sensitivity/Recall  :   37.13 %
# Specificity         :   80.17 %
# Precision           :   39.74 %
# --------------------------------------------

# %%
probs = clf_rfc.predict_proba(X_test)  
probs = probs[:, 1] 
fper, tper, thresholds = roc_curve(y_test, probs) 

plt.plot(fper, tper)
plt.plot([0,1], [0,1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Random Forest ROC curve')

# show the plot
plt.show()
print("The AUC ROC Score is {}".format(roc_auc_score(y_test, predictions_rfc)))
# Out:
# The AUC ROC Score is 0.5864726243715102

# %%
importance = clf_rfc.feature_importances_

# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))

# plot feature importance
figure(figsize=(20, 20))
plt.bar([x for x in range(len(importance))], importance)
plt.xticks(list(range(0,13)))
plt.show()
# Out:
# Feature: 0, Score: 0.04868
# Feature: 1, Score: 0.02578
# Feature: 2, Score: 0.00056
# Feature: 3, Score: 0.21712
# Feature: 4, Score: 0.15731
# Feature: 5, Score: 0.15169
# Feature: 6, Score: 0.09500
# Feature: 7, Score: 0.04916
# Feature: 8, Score: 0.11175
# Feature: 9, Score: 0.02397
# Feature: 10, Score: 0.02070
# Feature: 11, Score: 0.02270
# Feature: 12, Score: 0.07559

# %% [markdown]
# ### Logistic Regression

# %%
clf_lr = LogisticRegression(solver='saga').fit(X_train_smote,Y_train_smote) # solver
predictions_lr = clf_lr.predict(X_test.values)
# Out:
# C:\Users\Ishan Jain\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)

# %%
print(confusion_matrix(y_test, predictions_lr))
print("="*60)
print(classification_report(y_test, predictions_lr))
print("F1 Score : {}".format(f1_score(y_test,predictions_lr)))
# plot roc auc
# Out:
# [[313 161]
#  [ 69  98]]
# ============================================================
#               precision    recall  f1-score   support
#
#            0       0.82      0.66      0.73       474
#            1       0.38      0.59      0.46       167
#
#     accuracy                           0.64       641
#    macro avg       0.60      0.62      0.60       641
# weighted avg       0.70      0.64      0.66       641
#
# F1 Score : 0.46009389671361506

# %%
act = y_test.values
predict = predictions_lr
confusion_matrix_custom(act, predict)
# Out:
# Actual, Predicted Observations:   641 641
# --------------------------------------------
# Confusion Matrix
# --------------------------------------------
#                Predicted N Predicted Y
# Actual N       313            161
# Actual Y       69            98
# --------------------------------------------
# Total observations  :   641
# False Positives     :   161
# False Negatives     :   69
# Overall Accuracy    :   64.12 %
# Sensitivity/Recall  :   58.68 %
# Specificity         :   66.03 %
# Precision           :   37.84 %
# --------------------------------------------

# %%
probs = clf.predict_proba(X_test)  
probs = probs[:, 1] 
fper, tper, thresholds = roc_curve(y_test, probs) 
plt.plot(fper, tper)
plt.plot([0,1], [0,1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Logistic Regression ROC curve')
# show the plot
plt.show()

print("The AUC ROC Score is {}".format(roc_auc_score(y_test, predictions_lr)))
# Out:
# The AUC ROC Score is 0.6235819500240026

# %% [markdown]
# # Summary

# %% [raw]
# LightGBM - binary classification model has following:
#
#     1. Accuracy: 65%
#     2. Precision:39%
#     3. Recall: 62%
#     4. F-1 Score: 48%
#     5. AUC: 0.64

# %% [raw]
# Random Forest - binary classification model has following:
#
#     1. Accuracy: 69%
#     2. Precision:39%
#     3. Recall: 37%
#     4. F-1 Score: 38%
#     5. AUC: 0.59

# %% [raw]
# Logistics regression - binary classification model has following:
#
#     1. Accuracy: 64%
#     2. Precision:38%
#     3. Recall: 59%
#     4. F-1 Score: 46%
#     5. AUC: 0.62
